# %%
from tkinter import *

master = Tk()
Label(master, text='First Name').grid(row=0)
Label(master, text='Last Name').grid(row=1)
e1 = Entry(master)
e2 = Entry(master)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
mainloop()

# %%
from tkinter import *

master = Tk()
w = Scale(master, from_=0, to=42)
w.pack()
w = Scale(master, from_=0, to=200, orient=HORIZONTAL)
w.pack()
mainloop()

# %%
import tkinter as tk
from tkinter import ttk
import time

def start_progress():
    progress.start()

    # Simulate a task that takes time to complete
    for i in range(101):
      # Simulate some work
        time.sleep(0.05)  
        progress['value'] = i
        # Update the GUI
        root.update_idletasks()  
    progress.stop()

root = tk.Tk()
root.title("Progressbar Example")

# Create a progressbar widget
progress = ttk.Progressbar(root, orient="horizontal", length=300, mode="determinate")
progress.pack(pady=20)

# Button to start progress
start_button = tk.Button(root, text="Start Progress", command=start_progress)
start_button.pack(pady=10)

root.mainloop()

# %%
import tkinter as tk

def click_button(value):
    current = entry.get()
    entry.delete(0, tk.END)
    entry.insert(tk.END, current + value)

def clear():
    entry.delete(0, tk.END)

def calculate():
    try:
        result = eval(entry.get())
        entry.delete(0, tk.END)
        entry.insert(tk.END, result)
    except Exception as e:
        entry.delete(0, tk.END)
        entry.insert(tk.END, "Error")

# Crear la ventana principal
root = tk.Tk()
root.title("Calculadora")

# Caja de texto para mostrar los resultados
entry = tk.Entry(root, width=20, font=("Arial", 24), borderwidth=2, relief="solid", justify="right")
entry.grid(row=0, column=0, columnspan=4)

# Botones de la calculadora
buttons = [
    ('7', 1, 0), ('8', 1, 1), ('9', 1, 2), ('/', 1, 3),
    ('4', 2, 0), ('5', 2, 1), ('6', 2, 2), ('*', 2, 3),
    ('1', 3, 0), ('2', 3, 1), ('3', 3, 2), ('-', 3, 3),
    ('0', 4, 0), ('.', 4, 1), ('=', 4, 2), ('+', 4, 3),
    ('C', 5, 0)
]

# Crear los botones en la interfaz
for (text, row, col) in buttons:
    if text == "=":
        button = tk.Button(root, text=text, width=5, height=2, font=("Arial", 18), command=calculate)
    elif text == "C":
        button = tk.Button(root, text=text, width=5, height=2, font=("Arial", 18), command=clear)
    else:
        button = tk.Button(root, text=text, width=5, height=2, font=("Arial", 18), command=lambda t=text: click_button(t))
    button.grid(row=row, column=col, padx=5, pady=5)

# Iniciar la interfaz
root.mainloop()

# %%
#Primero hay que import tkinter
import tkinter 
#Arbimos la ventana y la mantenemos prendida.
m = Tk()

m.mainloop()

# %%
#Para poner un texto hay que poner lo sigunete.
from tkinter import *
root = Tk()
w = Label(root, text='Linealmente independiente')
#Dentro del Label van las características Label(master, option=value) 
w.pack()
root.mainloop()

# %%
#Para poder poner un botón, hayq que hacer los siguente:
import tkinter as tk

r = tk.Tk()
r.title('Counting Seconds')
button = tk.Button(r, text='Stop', width=25, command=r.destroy)
#Donde w=tk.Button(master, option=value)
button.pack()
r.mainloop()

# %%
#Para poder hacer que el usuario ingrese algo hay que poner la función ENTRY.capitalize
from tkinter import *

master = Tk()
Label(master, text='First Name').grid(row=0)
Label(master, text='Last Name').grid(row=1)
e1 = Entry(master)
e2 = Entry(master)
e1.grid(row=0, column=1)
e2.grid(row=1, column=1)
mainloop()

# %%
#Para poder seleccionar una opción hay que hacer los siguente:
from tkinter import *

master = Tk()
var1 = IntVar()
Checkbutton(master, text='chivas', variable=var1).grid(row=0, sticky=W)
var2 = IntVar()
Checkbutton(master, text='américa', variable=var2).grid(row=1, sticky=W)
mainloop()

# %%
#Para generar una lista hay que hacer lo siguinte:
from tkinter import *

top = Tk()
Lb = Listbox(top)
Lb.insert(4, 'Python')
Lb.insert(2, 'Java')
Lb.insert(1, 'C++')
Lb.insert(3, 'Any other')
Lb.pack()
top.mainloop()

# %%
#Para poner un scrollbar hay que hacer lo siguente:
from tkinter import *

root = Tk()
scrollbar = Scrollbar(root)
scrollbar.pack(side=LEFT, fill=Y)
mylist = Listbox(root, yscrollcommand=scrollbar.set)

for line in range(11):
    mylist.insert(END, 'Linea' + str(line))
    
mylist.pack(side=LEFT, fill=BOTH)
scrollbar.config(command=mylist.yview)
mainloop()

# %%
#Para hacer una barra de tareas
from tkinter import *

root = Tk()
menu = Menu(root)
root.config(menu=menu)
filemenu = Menu(menu)
menu.add_cascade(label='Archivos', menu=filemenu)
filemenu.add_command(label='Nuevos')
filemenu.add_command(label='Kevin´s...')
filemenu.add_separator()
filemenu.add_command(label='Exit', command=root.quit)
helpmenu = Menu(menu)
menu.add_cascade(label='Help', menu=helpmenu)
helpmenu.add_command(label='About')
mainloop()

# %%
#Para hacer una lista
import tkinter as tk
from tkinter import ttk

def select(event):
    selected_item = combo_box.get()
    label.config(text="Selected Item: " + selected_item)

root = tk.Tk()
root.title("Combobox Example")

# Create a label
label = tk.Label(root, text="Selected Item: ")
label.pack(pady=10)

# Create a Combobox widget
combo_box = ttk.Combobox(root, values=["Option 1", "Option 2", "Option 3"])
combo_box.pack(pady=5)

# Set default value
combo_box.set("Option 1")

# Bind event to selection
combo_box.bind("<<ComboboxSelected>>", select)

root.mainloop()
